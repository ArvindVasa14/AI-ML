# %%
#toddler sleeping pattern : Circadian Clocks

# %%
# hypothesis testing assignment

# %%
""" toddler sleeping pattern : Circadian Clocks
Parents of toddlers carefully guard and manage when and for how long their 
babies nap during the day and sleep at night. 

curious to understand.

data from the C.S. Mott Children's Hospital in Ann Arbor, Michigan 
to answer 3 burning questions:

Question 1: At what time do napping babies in the U.S. sleep at night?

Question 2: Is night bedtime for napping babies in the U.S. later than that of non-napping babies?

Question 3: Is sleep duration for napping babies in the U.S. different than 
that of non-napping babies?



hints:-

To answer Question 1, 
calculate a 95% confidence .
lower and upper confidence bounds . 

To answer Question 2, 
calculate sm.stats.ttest_ind .

To answer Question 3, 
calculate sm.stats.ttest_ind. 

find the confidence intervals 
and hypothesis tests to generate conclusions.  """

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm

import numpy as np
import warnings
warnings.filterwarnings("ignore")
import os
os.getcwd
pd.set_option('display.max_columns', 30)

# %%
#In the variable "Napping", 1 represents nappers and 0 represents non-nappers.

# %%
sleep=pd.read_csv("sleep_kid.csv")

# %%
sleep.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     sex  age (months)  dlmo time  days napped  \
# 0           0             0  female          33.7      19.24            0
# 1           1             1  female          31.5      18.27            0
# 2           2             2    male          31.9      19.14            0
# 3           3             3  female          31.6      19.69            0
# 4           4             4  female          33.0      19.52            0
#
#    napping  nap lights outl time  nap sleep onset  nap midsleep  \
# 0        0                   NaN              NaN           NaN
# 1        0                   NaN              NaN           NaN
# 2        0                   NaN              NaN           NaN
# 3        0                   NaN              NaN           NaN
# 4        0                   NaN              NaN           NaN
#
#    nap sleep offset  nap wake time  nap duration  nap time in bed  \
# ...

# %%
sleep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    20 non-null     int64
#  1   Unnamed: 0.1                  20 non-null     int64
#  2   sex                           20 non-null     object
#  3   age (months)                  20 non-null     float64
#  4   dlmo time                     20 non-null     float64
#  5   days napped                   20 non-null     int64
#  6   napping                       20 non-null     int64
#  7   nap lights outl time          15 non-null     float64
#  8   nap sleep onset               15 non-null     float64
#  9   nap midsleep                  15 non-null     float64
#  10  nap sleep offset              15 non-null     float64
#  11  nap wake time                 15 non-null     float64
# ...

# %%
df=sleep.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1)

# %%
df.head()
# Out:
#       sex  age (months)  dlmo time  days napped  napping  \
# 0  female          33.7      19.24            0        0
# 1  female          31.5      18.27            0        0
# 2    male          31.9      19.14            0        0
# 3  female          31.6      19.69            0        0
# 4  female          33.0      19.52            0        0
#
#    nap lights outl time  nap sleep onset  nap midsleep  nap sleep offset  \
# 0                   NaN              NaN           NaN               NaN
# 1                   NaN              NaN           NaN               NaN
# 2                   NaN              NaN           NaN               NaN
# 3                   NaN              NaN           NaN               NaN
# 4                   NaN              NaN           NaN               NaN
#
#    nap wake time  nap duration  nap time in bed  night bedtime  \
# 0            NaN           NaN              NaN          20.45
# ...

# %%
df.shape
# Out:
# (20, 24)

# %%
# Create dataframes for bedtimes for nappers and non-nappers
nap_bedtime = df[df.napping == 1]
no_nap_bedtime = df[df.napping == 0]

# %%
nap_bedtime.head()
# Out:
#       sex  age (months)  dlmo time  days napped  napping  \
# 5  female          36.2      18.22            4        1
# 6    male          36.3      19.28            1        1
# 7    male          30.0      21.06            5        1
# 8    male          33.2      19.38            2        1
# 9  female          37.1      19.93            3        1
#
#    nap lights outl time  nap sleep onset  nap midsleep  nap sleep offset  \
# 5                 14.00            14.22         15.00             15.78
# 6                 14.75            15.03         15.92             16.80
# 7                 13.09            13.43         14.44             15.46
# 8                 14.41            14.42         15.71             17.01
# 9                 13.12            13.42         14.31             15.19
#
#    nap wake time  nap duration  nap time in bed  night bedtime  \
# 5          16.28         93.75           137.00          19.95
# ...

# %%
nap_bedtime.shape
# Out:
# (15, 24)

# %%
no_nap_bedtime.head()
# Out:
#       sex  age (months)  dlmo time  days napped  napping  \
# 0  female          33.7      19.24            0        0
# 1  female          31.5      18.27            0        0
# 2    male          31.9      19.14            0        0
# 3  female          31.6      19.69            0        0
# 4  female          33.0      19.52            0        0
#
#    nap lights outl time  nap sleep onset  nap midsleep  nap sleep offset  \
# 0                   NaN              NaN           NaN               NaN
# 1                   NaN              NaN           NaN               NaN
# 2                   NaN              NaN           NaN               NaN
# 3                   NaN              NaN           NaN               NaN
# 4                   NaN              NaN           NaN               NaN
#
#    nap wake time  nap duration  nap time in bed  night bedtime  \
# 0            NaN           NaN              NaN          20.45
# ...

# %%
no_nap_bedtime.shape
# Out:
# (5, 24)

# %%
Question 1: At what time do napping babies in the U.S. sleep at night?
hint :- use the column ["night bedtime"]

# %% [markdown]
# ##### Question 2: Is night bedtime for napping babies in the U.S. later than that of non-napping babies?

# %%
 #hint :- # Mean night bedtime for nappers and non_nappers

# %% [markdown]
# ##### Q3: Is sleep duration for napping babies in the U.S. different than that of non-napping babies?

# %%
hint :- use the column
    ["night sleep duration"]
